# %% [markdown]
# # WeatherPy - Created by Mitty

# %% [markdown]
# ## Import Dependencies

# %%
# Dependencies and Setup
#%matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import tkinter
import os
import gmaps
import math

# Google developer API key
from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Import API Keys

# %%
# Import API key
from api_keys import api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
random_cities_to_generate = 2500
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=random_cities_to_generate)
lngs = np.random.uniform(low=-180.000, high=180.000, size=random_cities_to_generate)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print (f'\nTotal no. of unique cities generated: {len(cities)}\n')
print (f'Make sure to change variable: "random_cities_to_generate" to have sufficient cities selected since we may not get data for all 500 ')
# Out:
# Total no. of unique cities generated: 852
#
# Make sure to change variable: "random_cities_to_generate" to have sufficient cities selected since we may not get data for all 500

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#lets define all Variables we need
cities_selected=[]
lat =[]
lon =[]
temp_max =[]
humidity = []
wind_speed = []
cloudiness = []
country = []
date = []
error = 0

#define units we want
units = "metric"
localtime = time.asctime( time.localtime(time.time()) )

print (f'-----------------------------\nBeginning Data Retrieval\n-----------------------------')
# window1 = tkinter.Tk()
# window1.title("Message from mitty")
# label = tkinter.Label(window1, text = "\nData Retrieval could take some time\n\n Close window to continue\n").pack()
# window1.mainloop()

#loop through all cities in our list: cities
for idx, city in enumerate(cities):    
    # Save config information and Build query URL
    url = "http://api.openweathermap.org/data/2.5/weather?"    
    query_url = f"{url}appid={api_key}&units={units}&q={city}"
    
    #check to see if the reponse has code 200. if it does not skip it
    if requests.get(query_url).status_code == 200:
        print (f'Processing Record {idx+1} of Set of {len(cities)} FOUND & ADDED: |{city}')
        response = requests.get(query_url).json()
        city
        cities_selected.append(city)
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        temp_max.append(response['main']['temp_max'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    else:
        print (f'Processing Record {idx+1} of Set of {len(cities)} NOT FOUND: |{city}')

        

#print the stats for better understanding        
print (f'\n-----------------------------\nResults:\n-----------------------------')
print (f'Total no. of cities that we were able to retrieve data for: {len(cities_selected)} of {len(cities)} : {100*len(cities_selected)/len(cities)}%')
if (len(cities_selected)<500): 
    print (f'WARNING NOT ENOUGH CITIES IN DATASET. PLEASE INCREASE random_cities_to_generate AND RERUN ANALYSIS TO GET ATLEAST 500')
    error = 1
    
# window2 = tkinter.Tk()
# window2.title("Message from mitty")
# if error == 0:
#     label = tkinter.Label(window2, text = f'\nTotal no. of cities that we were able to retrieve data for: {len(cities_selected)} of {len(cities)} : {100*len(cities_selected)/len(cities):.2f}%\n').pack()
# else:
#     label = tkinter.Label(window2, text = f'\nWARNING NOT ENOUGH CITIES IN DATASET: {len(cities_selected)} of 500 needed\nPLEASE INCREASE random_cities_to_generate AND RERUN ANALYSIS TO GET ATLEAST 500').pack()
# window2.mainloop()
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of
# Processing Record 688 of Set of 852 FOUND & ADDED: |culfa
# Processing Record 689 of Set of 852 FOUND & ADDED: |kathu
# Processing Record 690 of Set of 852 FOUND & ADDED: |santa cruz
# Processing Record 691 of Set of 852 NOT FOUND: |macaboboni
# Processing Record 692 of Set of 852 FOUND & ADDED: |kununurra
# Processing Record 693 of Set of 852 FOUND & ADDED: |sale
# Processing Record 694 of Set of 852 FOUND & ADDED: |aswan
# Processing Record 695 of Set of 852 NOT FOUND: |alotau
# Processing Record 696 of Set of 852 FOUND & ADDED: |nizwa
# Processing Record 697 of Set of 852 FOUND & ADDED: |tokoroa
# Processing Record 698 of Set of 852 FOUND & ADDED: |flin flon
# Processing Record 699 of Set of 852 NOT FOUND: |temaraia
# Processing Record 700 of Set of 852 NOT FOUND: |tasbuget
# Processing Record 701 of Set of 852 FOUND & ADDED: |smithers
# Processing Record 702 of Set of 852 FOUND & ADDED: |khandyga
# Processing Record 703 of Set of 852 NOT FOUND: |tarhunah
# Processing Record 704 of Set of 852 FOUND & ADDED: |san francisco del mar
# Processing Record 705 of Set of 852 FOUND & ADDED: |panzhihua
# Processing Record 706 of Set of 852 FOUND & ADDED: |dunda
# Processing Record 707 of Set of 852 FOUND & ADDED: |haines junction
# Processing Record 708 of Set of 852 FOUND & ADDED: |sibolga
# Processing Record 709 of Set of 852 FOUND & ADDED: |visby
# Processing Record 710 of Set of 852 FOUND & ADDED: |sangar
# Processing Record 711 of Set of 852 FOUND & ADDED: |oktyabrskiy
# Processing Record 712 of Set of 852 FOUND & ADDED: |tourlaville
# Processing Record 713 of Set of 852 FOUND & ADDED: |robertsport
# Processing Record 714 of Set of 852 FOUND & ADDED: |shimoda
# Processing Record 715 of Set of 852 FOUND & ADDED: |limbang
# Processing Record 716 of Set of 852 FOUND & ADDED: |gamba
# Processing Record 717 of Set of 852 FOUND & ADDED: |sri aman
# Processing Record 718 of Set of 852 FOUND & ADDED: |novo aripuana
# Processing Record 719 of Set of 852 FOUND & ADDED: |punta gorda
# Processing Record 720 of Set of 852 FOUND & ADDED: |coihaique
# Processing Record 721 of Set of 852 FOUND & ADDED: |chekalin
# Processing Record 722 of Set of 852 FOUND & ADDED: |maltahohe
# Processing Record 723 of Set of 852 FOUND & ADDED: |egvekinot
# Processing Record 724 of Set of 852 FOUND & ADDED: |bani walid
# Processing Record 725 of Set of 852 FOUND & ADDED: |liverpool
# Processing Record 726 of Set of 852 FOUND & ADDED: |zhuanghe
# Processing Record 727 of Set of 852 NOT FOUND: |mrirt
# Processing Record 728 of Set of 852 FOUND & ADDED: |tonstad
# Processing Record 729 of Set of 852 FOUND & ADDED: |sosnovo-ozerskoye
# Processing Record 730 of Set of 852 FOUND & ADDED: |kaoma
# Processing Record 731 of Set of 852 FOUND & ADDED: |fort william
# Processing Record 732 of Set of 852 FOUND & ADDED: |labuhan
# Processing Record 733 of Set of 852 FOUND & ADDED: |iowa city
# Processing Record 734 of Set of 852 FOUND & ADDED: |santa marta
# Processing Record 735 of Set of 852 FOUND & ADDED: |quelimane
# Processing Record 736 of Set of 852 NOT FOUND: |rungata
# Processing Record 737 of Set of 852 FOUND & ADDED: |madang
# Processing Record 738 of Set of 852 FOUND & ADDED: |yatou
# Processing Record 739 of Set of 852 FOUND & ADDED: |zyryanka
# Processing Record 740 of Set of 852 FOUND & ADDED: |havre
# Processing Record 741 of Set of 852 FOUND & ADDED: |manono
# Processing Record 742 of Set of 852 FOUND & ADDED: |tutoia
# Processing Record 743 of Set of 852 NOT FOUND: |umzimvubu
# Processing Record 744 of Set of 852 FOUND & ADDED: |katsuura
# Processing Record 745 of Set of 852 FOUND & ADDED: |louisville
# Processing Record 746 of Set of 852 FOUND & ADDED: |maniitsoq
# Processing Record 747 of Set of 852 NOT FOUND: |jyvaskyla
# Processing Record 748 of Set of 852 FOUND & ADDED: |belle fourche
# Processing Record 749 of Set of 852 FOUND & ADDED: |panguna
# Processing Record 750 of Set of 852 FOUND & ADDED: |diamantino
# Processing Record 751 of Set of 852 FOUND & ADDED: |manggar
# Processing Record 752 of Set of 852 FOUND & ADDED: |tarakan
# Processing Record 753 of Set of 852 FOUND & ADDED: |pincher creek
# Processing Record 754 of Set of 852 FOUND & ADDED: |rio gallegos
# Processing Record 755 of Set of 852 FOUND & ADDED: |kommunisticheskiy
# Processing Record 756 of Set of 852 FOUND & ADDED: |berekum
# Processing Record 757 of Set of 852 FOUND & ADDED: |luang prabang
# Processing Record 758 of Set of 852 FOUND & ADDED: |mookane
# Processing Record 759 of Set of 852 NOT FOUND: |grajau
# Processing Record 760 of Set of 852 FOUND & ADDED: |divnoye
# Processing Record 761 of Set of 852 NOT FOUND: |nguiu
# Processing Record 762 of Set of 852 FOUND & ADDED: |moron
# Processing Record 763 of Set of 852 FOUND & ADDED: |nome
# Processing Record 764 of Set of 852 FOUND & ADDED: |tevaitoa
# Processing Record 765 of Set of 852 NOT FOUND: |ahuatempan
# Processing Record 766 of Set of 852 FOUND & ADDED: |melfi
# Processing Record 767 of Set of 852 FOUND & ADDED: |the pas
# Processing Record 768 of Set of 852 FOUND & ADDED: |altamira
# Processing Record 769 of Set of 852 FOUND & ADDED: |sterling
# Processing Record 770 of Set of 852 FOUND & ADDED: |christchurch
# Processing Record 771 of Set of 852 FOUND & ADDED: |tommot
# Processing Record 772 of Set of 852 FOUND & ADDED: |rawson
# Processing Record 773 of Set of 852 FOUND & ADDED: |leshukonskoye
# Processing Record 774 of Set of 852 FOUND & ADDED: |port-gentil
# Processing Record 775 of Set of 852 FOUND & ADDED: |colac
# Processing Record 776 of Set of 852 FOUND & ADDED: |farkhor
# Processing Record 777 of Set of 852 FOUND & ADDED: |pasighat
# Processing Record 778 of Set of 852 FOUND & ADDED: |halifax
# Processing Record 779 of Set of 852 FOUND & ADDED: |fort-shevchenko
# Processing Record 780 of Set of 852 FOUND & ADDED: |mayskiy
# Processing Record 781 of Set of 852 NOT FOUND: |mentok
# Processing Record 782 of Set of 852 FOUND & ADDED: |kutum
# Processing Record 783 of Set of 852 FOUND & ADDED: |evanston
# Processing Record 784 of Set of 852 NOT FOUND: |bocaranga
# Processing Record 785 of Set of 852 FOUND & ADDED: |kerchevskiy
# Processing Record 786 of Set of 852 FOUND & ADDED: |kapit
# Processing Record 787 of Set of 852 FOUND & ADDED: |cherrapunji
# Processing Record 788 of Set of 852 FOUND & ADDED: |taytsy
# Processing Record 789 of Set of 852 FOUND & ADDED: |sechura
# Processing Record 790 of Set of 852 FOUND & ADDED: |montepuez
# Processing Record 791 of Set of 852 FOUND & ADDED: |plettenberg bay
# Processing Record 792 of Set of 852 FOUND & ADDED: |marsaxlokk
# Processing Record 793 of Set of 852 FOUND & ADDED: |nhulunbuy
# Processing Record 794 of Set of 852 FOUND & ADDED: |roswell
# Processing Record 795 of Set of 852 FOUND & ADDED: |kralendijk
# Processing Record 796 of Set of 852 FOUND & ADDED: |vidim
# Processing Record 797 of Set of 852 NOT FOUND: |kamenskoye
# Processing Record 798 of Set of 852 FOUND & ADDED: |zeya
# Processing Record 799 of Set of 852 FOUND & ADDED: |cvikov
# Processing Record 800 of Set of 852 FOUND & ADDED: |revyakino
# Processing Record 801 of Set of 852 FOUND & ADDED: |port keats
# Processing Record 802 of Set of 852 FOUND & ADDED: |canto do buriti
# Processing Record 803 of Set of 852 FOUND & ADDED: |coahuayana
# Processing Record 804 of Set of 852 FOUND & ADDED: |santa rosa
# Processing Record 805 of Set of 852 FOUND & ADDED: |moree
# Processing Record 806 of Set of 852 FOUND & ADDED: |half moon bay
# Processing Record 807 of Set of 852 FOUND & ADDED: |mahibadhoo
# Processing Record 808 of Set of 852 FOUND & ADDED: |upata
# Processing Record 809 of Set of 852 NOT FOUND: |urdzhar
# Processing Record 810 of Set of 852 FOUND & ADDED: |raybag
# Processing Record 811 of Set of 852 FOUND & ADDED: |ptghni
# Processing Record 812 of Set of 852 FOUND & ADDED: |kuryk
# Processing Record 813 of Set of 852 FOUND & ADDED: |matagami
# Processing Record 814 of Set of 852 FOUND & ADDED: |mangan
# Processing Record 815 of Set of 852 FOUND & ADDED: |riohacha
# Processing Record 816 of Set of 852 FOUND & ADDED: |morondava
# Processing Record 817 of Set of 852 FOUND & ADDED: |lazarev
# Processing Record 818 of Set of 852 FOUND & ADDED: |valuyki
# Processing Record 819 of Set of 852 FOUND & ADDED: |la serena
# Processing Record 820 of Set of 852 FOUND & ADDED: |herat
# Processing Record 821 of Set of 852 FOUND & ADDED: |chernyshevskiy
# Processing Record 822 of Set of 852 FOUND & ADDED: |skibbereen
# Processing Record 823 of Set of 852 FOUND & ADDED: |seydi
# Processing Record 824 of Set of 852 FOUND & ADDED: |kaseda
# Processing Record 825 of Set of 852 FOUND & ADDED: |danville
# Processing Record 826 of Set of 852 NOT FOUND: |bargal
# Processing Record 827 of Set of 852 FOUND & ADDED: |norton shores
# Processing Record 828 of Set of 852 FOUND & ADDED: |villa carlos paz
# Processing Record 829 of Set of 852 NOT FOUND: |utiroa
# Processing Record 830 of Set of 852 FOUND & ADDED: |juneau
# Processing Record 831 of Set of 852 FOUND & ADDED: |veraval
# Processing Record 832 of Set of 852 FOUND & ADDED: |yeppoon
# Processing Record 833 of Set of 852 FOUND & ADDED: |la union
# Processing Record 834 of Set of 852 FOUND & ADDED: |puerto madryn
# Processing Record 835 of Set of 852 NOT FOUND: |acarau
# Processing Record 836 of Set of 852 FOUND & ADDED: |sibut
# Processing Record 837 of Set of 852 FOUND & ADDED: |baker city
# Processing Record 838 of Set of 852 NOT FOUND: |meyungs
# Processing Record 839 of Set of 852 FOUND & ADDED: |bontang
# Processing Record 840 of Set of 852 FOUND & ADDED: |lodeynoye pole
# Processing Record 841 of Set of 852 FOUND & ADDED: |mtimbira
# Processing Record 842 of Set of 852 NOT FOUND: |solovetskiy
# Processing Record 843 of Set of 852 FOUND & ADDED: |susangerd
# Processing Record 844 of Set of 852 FOUND & ADDED: |saurimo
# Processing Record 845 of Set of 852 FOUND & ADDED: |magadan
# Processing Record 846 of Set of 852 FOUND & ADDED: |qena
# Processing Record 847 of Set of 852 FOUND & ADDED: |zapadnaya dvina
# Processing Record 848 of Set of 852 FOUND & ADDED: |jiwani
# Processing Record 849 of Set of 852 FOUND & ADDED: |yuncheng
# Processing Record 850 of Set of 852 FOUND & ADDED: |skara
# Processing Record 851 of Set of 852 FOUND & ADDED: |bilma
# Processing Record 852 of Set of 852 NOT FOUND: |cheyur
#
# -----------------------------
# Results:
# -----------------------------
# Total no. of cities that we were able to retrieve data for: 754 of 852 : 88.49765258215963%

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#lets create a dataframe to match City	Cloudiness	Country	Date	Humidity	Lat	Lng	Max Temp	Wind Speed
weather_dict = {
    "City": cities_selected,
    "Cloudiness": cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat": lat,
    "Lng":lon,
    "Max Temp": temp_max,
    "Wind Speed": wind_speed
      }
weather_data = pd.DataFrame(weather_dict)

# Write to Output File (CSV)
output_data_file = f'output_data/Cities_Data_{localtime}.csv'
weather_data.to_csv(output_data_file, index=False)

#Display dataframe
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  longyearbyen          40      NO  1558476082        73  78.22  15.63
# 1       huarmey         100      PE  1558476083        91 -10.07 -78.15
# 2     upernavik          30      GL  1558476011        84  72.79 -56.15
# 3          doka          46      SD  1558476084        19  13.52  35.76
# 4  tres arroyos         100      AR  1558476085        59 -38.38 -60.28
#
#    Max Temp  Wind Speed
# 0     -3.00        3.60
# 1     19.04        9.27
# 2      0.64        0.55
# 3     35.24        1.89
# 4     10.04        2.38

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Plotting the cities selected

# %%
# Access maps with unique API key
gmaps.configure(api_key=gkey)

# Customize the size of the figure
figure_layout = {
    'width': '1000px',
    'height': '500px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

# Create the Layout
fig = gmaps.figure(layout=figure_layout)

# Assign the marker layer to cities
markers = gmaps.symbol_layer(weather_data[['Lat', 'Lng']], fill_color='green', stroke_color='green', scale=2)

# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
#Lets plot - Latitude vs. Temperature Plot
plt.title("City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.xlim(-90,90)
plt.ylabel("Max Temperature(F)")
plt.scatter(weather_data['Lat'], weather_data['Max Temp'], marker="o", facecolors="blue", alpha=0.7, edgecolors="black")
plt.grid()

plt.savefig(f'images/Lats_vs_Temps({localtime}).png')
plt.show()

# %% [markdown]
# ### Binned Max Temp Plot

# %%
bins = [-90+10*i for i in range(19)]
group_names = [-90+10*i+5 for i in range(18)]
temp1 = weather_data
temp1["Binned Lat"] = pd.cut(temp1["Lat"], bins, labels=group_names)
temp1 = temp1.groupby("Binned Lat")

plt.xticks(group_names, rotation='vertical')
plt.xlim(-85,85)
plt.grid()
plt.plot(group_names,temp1["Max Temp"].mean(), color = 'red')
plt.bar(group_names,temp1["Max Temp"].mean(), align='center', color ='blue', alpha=0.7, width=9)
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### Heat map showing the distribution of highest average temperature

# %%
figure_layout = {
    'width': '1000px',
    'height': '700px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

# Create a max temp Heatmap layer
fig = gmaps.figure(layout=figure_layout)

#Create zone Lat Long and Heat
x_heat_map =[]
y_heat_map =[]
max_temp_plot =[]
heat_binned = temp1["Max Temp"].mean()


for idx,bin in enumerate(group_names):
    for i in range(-180,180,10):
        x_heat_map.append(float(bin))
        y_heat_map.append(float(i))
        max_temp_plot.append(heat_binned[idx])

        
locations = pd.DataFrame(list(zip(x_heat_map, y_heat_map)), columns =['Lat', 'Lng'])

max_temp_plot = [0 if math.isnan(x) else x for x in max_temp_plot]
# print (min(max_temp_plot))
# max_temp_plot = max_temp_plot - min(max_temp_plot)

heat_layer = gmaps.heatmap_layer(locations, weights=max_temp_plot, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 50
heat_layer.point_radius = 10
fig.add_layer(markers)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='700px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
#Lets plot - Latitude vs. Humidity Plot
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.xlim(-90,90)
plt.ylim(0,105)
plt.ylabel("Humidity(%)")
plt.scatter(weather_data['Lat'], weather_data['Humidity'], marker="o", facecolors="yellow", alpha=0.7, edgecolors="black")
plt.grid()

plt.savefig(f'images/Lats_vs_Humidity({localtime}).png')
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
#Lets plot - Latitude vs. Cloudiness Plot
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.xlim(-90,90)
plt.ylim(0,105)
plt.ylabel("Cloudiness(%)")
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'], marker="o", facecolors="purple", alpha=0.7, edgecolors="black")
plt.grid()

plt.savefig(f'images/Lats_vs_Cloudiness({localtime}).png')
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
#Lets plot - Latitude vs. Wind Speed Plot
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.xlim(-90,90)
plt.ylim(0,105)
plt.ylabel("Wind Speed(mph)")
plt.scatter(weather_data['Lat'], weather_data['Cloudiness'], marker="o", facecolors="green", alpha=0.7, edgecolors="black")
plt.grid()

plt.savefig(f'images/Lats_vs_WindSpeed({localtime}).png')
plt.show()
